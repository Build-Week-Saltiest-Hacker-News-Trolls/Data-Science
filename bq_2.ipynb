# %%
# set env variable to json credential file of google cloud

import os
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '/Users/karthikmahendra/Desktop/Salty/salty-trolls-cce24104ff9f.json'

# %%
from google.cloud import bigquery
import time
import pandas as pd
import numpy as np

# %%
# setup client
bq_client = bigquery.Client()

# %%
#Query for pulling data of a username
QUERY = '''SELECT  * 
        FROM `bigquery-public-data.hacker_news.full_201510`
        WHERE `bigquery-public-data.hacker_news.full_201510`.by = "danmaz74"
        '''

# %%
df = bq_client.query(QUERY).to_dataframe()

# %%
df.shape
# Out:
# (1680, 13)

# %%
df['text'] = df['text'].str.encode('ascii', 'ignore').str.decode('ascii')

# %%
df.head()
# Out:
#          by  score        time title     type   url  \
# 0  danmaz74    NaN  1368003409  None  comment  None
# 1  danmaz74    NaN  1362914038  None  comment  None
# 2  danmaz74    NaN  1380696100  None  comment  None
# 3  danmaz74    NaN  1370794029  None  comment  None
# 4  danmaz74    NaN  1383740372  None  comment  None
#
#                                                 text     parent deleted  dead  \
# 0  "HackingItalia" has much better chances of suc...  5672999.0    None  None
# 1  The (not so) funny thing is that this has been...  5350893.0    None  None
# 2  Absolutely. There is also no clue that the pag...  6479777.0    None  None
# 3  Does anybody have ideas about how a small fore...  5849087.0    None  None
# 4  Great, I&#x27;ll try your service instead of d...  6681977.0    None  None
#
#    descendants       id ranking
# 0          NaN  5673213    None
# 1          NaN  5351456    None
# 2          NaN  6481042    None
# 3          NaN  5849372    None
# 4          NaN  6682294    None

# %%
import html,re

# %%
def decoder(text):
    """decode HTML text."""
    unescaped = html.unescape(text)
    return unescaped


def kill_html(text):
    """Remove html flags."""
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, ' ', text)
    return cleantext


def kill_url(text):
    """Remove URL with regex"""
    return ''.join(re.sub(r"http\S+", "", text))



df['cleaned_comment'] = df.text.apply(lambda x: kill_url(kill_html(decoder(x))))
# Out:
# -----------------------------------------------------------------------
# TypeError                             Traceback (most recent call last)
# <ipython-input-18-fbe5fcc184dd> in <module>
#      18
#      19
# ---> 20 df['cleaned_comment'] = df.text.apply(lambda x: kill_url(kill_html(decoder(x))))
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-18-fbe5fcc184dd> in <lambda>(x)
#      18
#      19
# ---> 20 df['cleaned_comment'] = df.text.apply(lambda x: kill_url(kill_html(decoder(x))))
#
# <ipython-input-18-fbe5fcc184dd> in decoder(text)
#       1 def decoder(text):
#       2     """decode HTML text."""
# ----> 3     unescaped = html.unescape(text)
#       4     return unescaped
#       5
#
# ~/anaconda3/lib/python3.7/html/__init__.py in unescape(s)
#     128     HTML 5 named character references defined in html.entities.html5.
#     129     """
# --> 130     if '&' not in s:
#     131         return s
#     132     return _charref.sub(_replace_charref, s)
#
# TypeError: argument of type 'NoneType' is not iterable

# %%
# job_config = bigquery.QueryJobConfig()
# now=time.time()
# query_job=bq_client.query(QUERY,location='US')
# res=query_job.result()
# print('query took:',round(time.time()-now,2),'s')
# Out:
# query took: 1.23 s

# %%
# now=time.time()
# destination_uri = "gs://karthikkm028-ds/*hacker.csv"
# dataset_ref = bq_client.dataset("hacker_news", project='bigquery-public-data')
# table_ref = dataset_ref.table("full_201510")

# extract_job = bq_client.extract_table(
#     table_ref,
#     destination_uri)
# extract_job.result()  # Waits for job to complete
# print('create table and write to GCS took:',round(time.time()-now,2),'s')

# %%
# gcs = gcsfs.GCSFileSystem(project='bigquery-public-data') 
# files=gcs.glob(destination_uri)
# df = pd.concat([pd.read_csv('gs://'+f) for f in files], ignore_index=True)
# print('read csv took:',round(time.time()-now,2),'s')
# Out:
# /Users/karthikmahendra/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3214: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):
# /Users/karthikmahendra/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3214: DtypeWarning: Columns (1,2,5,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):
# read csv took: 1421.34 s

# %%
df_drop = df.drop(columns= ['score','title','url','deleted','dead','descendants','ranking'])

# %%
df_drop.head()
# Out:
#          by        time     type  \
# 0  danmaz74  1406974965  comment
# 1  danmaz74  1436624566  comment
# 2  danmaz74  1338129641  comment
# 3  danmaz74  1421700122  comment
# 4  danmaz74  1352372488  comment
#
#                                                 text     parent       id
# 0                               &quot;Adapter&quot;?  8124494.0  8124572
# 1  For the Romans, an often cited reason for the ...  9868765.0  9869850
# 2                           And that's all I need ;)  4030140.0  4030164
# 3  With a couple of books I reference often, I&#x...  8913265.0  8913948
# 4  On the other hand, 99.7% of my readers didn't ...  4757225.0  4757283

# %%
df_drop.shape
# Out:
# (1680, 6)

# %%
df_drop.dtypes
# Out:
# by         object
# time        int64
# type       object
# text       object
# parent    float64
# id          int64
# dtype: object

# %%
#df1 = df_drop.head(100)

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

# %%
df_drop['text']=df_drop['text'].apply(str)

# %%
df_drop['text']=df_drop['text'].str.encode('ascii',errors='ignore')

# %%
type(df_drop['text'][0])
# Out:
# str

# %%
s = sia.polarity_scores(df_drop['text'][0])

# %%
s
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
s['neg']
# Out:
# 0.0

# %%
#df_drop['neg'][0] = sia.polarity_scores(df_drop['text'][0])['neg']

# %%
sia.polarity_scores(df_drop['text'][0])
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
df_drop['neg']=np.zeros(df_drop.shape[0])
df_drop['pos']=np.zeros(df_drop.shape[0])
df_drop['neu']=np.zeros(df_drop.shape[0])

# %%
# populate vader sentiments in additional cols
for idx,x in df_drop['text'].iteritems():
    #print (idx,x)
    df_drop['neg'][idx] = sia.polarity_scores(x)['neg']
    df_drop['pos'][idx] = sia.polarity_scores(x)['pos']
    df_drop['neu'][idx]= sia.polarity_scores(x)['neu']
# Out:
# /Users/karthikmahendra/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/karthikmahendra/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/karthikmahendra/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
df_drop.head()
# Out:
#          by        time     type  \
# 0  danmaz74  1406974965  comment
# 1  danmaz74  1436624566  comment
# 2  danmaz74  1338129641  comment
# 3  danmaz74  1421700122  comment
# 4  danmaz74  1352372488  comment
#
#                                                 text     parent       id  \
# 0                            b'&quot;Adapter&quot;?'  8124494.0  8124572
# 1  b'For the Romans, an often cited reason for th...  9868765.0  9869850
# 2                        b"And that's all I need ;)"  4030140.0  4030164
# 3  b'With a couple of books I reference often, I&...  8913265.0  8913948
# 4  b"On the other hand, 99.7% of my readers didn'...  4757225.0  4757283
#
#      neg    pos    neu
# 0  0.000  0.000  1.000
# 1  0.080  0.000  0.920
# 2  0.000  0.322  0.678
# 3  0.000  0.087  0.913
# 4  0.053  0.138  0.810

# %%
# Set threshold of .5 for filtering positive and negative comments. drop comments with value 1 

df_neg = df_drop[(df_drop['neg']> 0.5) & (df_drop['neg'] !=1)]
df_pos = df_drop[(df_drop['pos']> 0.5) & (df_drop['pos'] !=1)]

# %%
df_neg = df_neg.sort_values(['neg'],ascending=False)
df_pos =df_pos.sort_values(['pos'],ascending=False)

# %%
# top negative comments
df_neg.head()
# Out:
#             by        time     type  \
# 1345  danmaz74  1375567037  comment
# 434   danmaz74  1431625440  comment
#
#                                                  text     parent       id  \
# 1345  I&#x27;m disgusted, this is such a rigged game.  6152872.0  6153574
# 434                                   They lost us...  9546379.0  9546430
#
#         neg  pos    neu
# 1345  0.541  0.0  0.459
# 434   0.535  0.0  0.465

# %%
# top positive comments
df_pos.head()
# Out:
#             by        time     type  \
# 414   danmaz74  1441294856  comment
# 699   danmaz74  1318260807  comment
# 1244  danmaz74  1379140076  comment
# 14    danmaz74  1438182885  comment
# 510   danmaz74  1368988078  comment
# 589   danmaz74  1320396226  comment
# 1218  danmaz74  1352378421  comment
# 963   danmaz74  1429266929  comment
# 1078  danmaz74  1418308852  comment
# 1651  danmaz74  1338135787  comment
#
#                                                  text      parent        id  \
# 414                             Thanks, great answer!  10165509.0  10165541
# 699                              Indeed... good luck!   3094081.0   3094183
# 1244              Yes - yes - camera button, please!!   6384270.0   6384874
# 14                               You&#x27;re welcome!   9969067.0   9969154
# 510                                        Exactly :)   5733149.0   5733876
# 589                         Good luck with it then :)   3193271.0   3195378
# 1218            Ok, I'll look for a solution. Thanks!   4757386.0   4757574
# 963                                 Good job David ;)   9391828.0   9393355
# 1078                  Font awesome has spinners... :)   8734901.0   8734915
# 1651  Cool - so for FF there is already a solution :)   4030324.0   4030348
#
#       neg    pos    neu
# 414   0.0  0.879  0.121
# 699   0.0  0.861  0.139
# 1244  0.0  0.806  0.194
# 14    0.0  0.767  0.233
# 510   0.0  0.750  0.250
# 589   0.0  0.748  0.252
# 1218  0.0  0.719  0.281
# 963   0.0  0.706  0.294
# 1078  0.0  0.703  0.297
# 1651  0.0  0.695  0.305

# %%
from datetime import datetime

#convert 

df_pos['time']=pd.to_datetime(df_pos['time'],unit='s')

# %%
df['time']=pd.to_datetime(df['time'],unit='s')

# %%
s = s.encode('ascii',errors='ignore')
# Out:
#             by  score                time  \
# 0     danmaz74    NaN 2014-08-02 10:22:45
# 1     danmaz74    NaN 2015-07-11 14:22:46
# 2     danmaz74    NaN 2012-05-27 14:40:41
# 3     danmaz74    NaN 2015-01-19 20:42:02
# 4     danmaz74    NaN 2012-11-08 11:01:28
# 5     danmaz74    NaN 2015-06-23 19:07:54
# 6     danmaz74    NaN 2013-10-17 10:28:12
# 7     danmaz74    NaN 2012-11-10 19:35:09
# 8     danmaz74    NaN 2013-06-25 14:20:07
# 9     danmaz74    NaN 2012-10-10 11:43:13
# 10    danmaz74    NaN 2012-02-19 07:13:03
# 11    danmaz74    NaN 2011-10-23 14:08:34
# 12    danmaz74    NaN 2013-08-31 12:27:47
# 13    danmaz74    NaN 2013-07-05 19:03:37
# 14    danmaz74    NaN 2015-07-29 15:14:45
# 15    danmaz74    NaN 2015-04-06 18:05:10
# 16    danmaz74    NaN 2011-10-26 17:59:19
# 17    danmaz74    NaN 2014-07-26 07:19:12
# 18    danmaz74    NaN 2011-12-30 15:21:45
# 19    danmaz74    NaN 2014-08-17 11:09:06
# 20    danmaz74    NaN 2014-04-01 22:59:08
# 21    danmaz74    NaN 2013-09-19 20:13:08
# 22    danmaz74    NaN 2014-06-11 20:11:31
# 23    danmaz74    NaN 2015-06-02 11:39:38
# 24    danmaz74    NaN 2015-06-05 07:04:22
# 25    danmaz74    NaN 2013-10-23 08:32:25
# 26    danmaz74    NaN 2011-10-19 18:15:32
# 27    danmaz74    NaN 2014-06-22 11:58:16
# 28    danmaz74    NaN 2013-07-01 06:08:26
# 29    danmaz74    NaN 2013-09-01 09:10:42
# ...        ...    ...                 ...
# 1650  danmaz74    NaN 2013-05-13 10:14:24
# 1651  danmaz74    NaN 2012-05-27 16:23:07
# 1652  danmaz74    NaN 2015-06-18 15:00:02
# 1653  danmaz74    NaN 2011-09-24 12:37:57
# 1654  danmaz74    NaN 2014-02-03 11:19:34
# 1655  danmaz74    NaN 2013-06-14 14:56:41
# 1656  danmaz74    NaN 2015-09-11 23:06:34
# 1657  danmaz74    NaN 2013-10-15 10:20:41
# 1658  danmaz74    NaN 2013-10-15 21:56:46
# 1659  danmaz74    NaN 2013-10-16 10:17:52
# 1660  danmaz74    NaN 2014-03-08 20:27:26
# 1661  danmaz74    NaN 2013-01-18 20:39:33
# 1662  danmaz74    NaN 2014-12-30 11:27:32
# 1663  danmaz74    NaN 2013-09-19 17:23:14
# 1664  danmaz74    NaN 2014-06-12 10:03:04
# 1665  danmaz74    NaN 2011-08-31 11:04:10
# 1666  danmaz74    NaN 2013-03-29 08:42:52
# 1667  danmaz74    NaN 2013-07-19 18:55:05
# 1668  danmaz74    NaN 2013-10-21 10:09:51
# 1669  danmaz74    NaN 2015-08-27 11:53:29
# 1670  danmaz74    NaN 2015-06-05 15:28:48
# 1671  danmaz74    NaN 2012-10-16 11:06:29
# 1672  danmaz74    NaN 2013-09-01 14:06:41
# 1673  danmaz74    NaN 2015-07-05 23:02:11
# 1674  danmaz74    NaN 2014-12-07 16:18:37
# 1675  danmaz74    NaN 2014-11-04 13:54:08
# 1676  danmaz74    NaN 2015-05-07 16:43:08
# 1677  danmaz74    NaN 2015-07-29 10:04:20
# 1678  danmaz74    1.0 2013-09-14 11:23:36
# 1679  danmaz74   60.0 2012-10-10 10:47:02
#
#                                                   title     type  \
# 0                                                  None  comment
# 1                                                  None  comment
# 2                                                  None  comment
# 3                                                  None  comment
# 4                                                  None  comment
# 5                                                  None  comment
# 6                                                  None  comment
# 7                                                  None  comment
# 8                                                  None  comment
# 9                                                  None  comment
# 10                                                 None  comment
# 11                                                 None  comment
# 12                                                 None  comment
# 13                                                 None  comment
# 14                                                 None  comment
# 15                                                 None  comment
# 16                                                 None  comment
# 17                                                 None  comment
# 18                                                 None  comment
# 19                                                 None  comment
# 20                                                 None  comment
# 21                                                 None  comment
# 22                                                 None  comment
# 23                                                 None  comment
# 24                                                 None  comment
# 25                                                 None  comment
# 26                                                 None  comment
# 27                                                 None  comment
# 28                                                 None  comment
# 29                                                 None  comment
# ...                                                 ...      ...
# 1650                                               None  comment
# 1651                                               None  comment
# 1652                                               None  comment
# 1653                                               None  comment
# 1654                                               None  comment
# 1655                                               None  comment
# 1656                                               None  comment
# 1657                                               None  comment
# 1658                                               None  comment
# 1659                                               None  comment
# 1660                                               None  comment
# 1661                                               None  comment
# 1662                                               None  comment
# 1663                                               None  comment
# 1664                                               None  comment
# 1665                                               None  comment
# 1666                                               None  comment
# 1667                                               None  comment
# 1668                                               None  comment
# 1669                                               None  comment
# 1670                                               None  comment
# 1671                                               None  comment
# 1672                                               None  comment
# 1673                                               None  comment
# 1674                                               None  comment
# 1675                                               None  comment
# 1676                                               None  comment
# 1677                                               None  comment
# 1678              Guide To Conversion Rate Optimization    story
# 1679  ABalytics.js: Client-side A/B Testing With Goo...    story
#
#                                                     url  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# 5                                                  None
# 6                                                  None
# 7                                                  None
# 8                                                  None
# 9                                                  None
# 10                                                 None
# 11                                                 None
# 12                                                 None
# 13                                                 None
# 14                                                 None
# 15                                                 None
# 16                                                 None
# 17                                                 None
# 18                                                 None
# 19                                                 None
# 20                                                 None
# 21                                                 None
# 22                                                 None
# 23                                                 None
# 24                                                 None
# 25                                                 None
# 26                                                 None
# 27                                                 None
# 28                                                 None
# 29                                                 None
# ...                                                 ...
# 1650                                               None
# 1651                                               None
# 1652                                               None
# 1653                                               None
# 1654                                               None
# 1655                                               None
# 1656                                               None
# 1657                                               None
# 1658                                               None
# 1659                                               None
# 1660                                               None
# 1661                                               None
# 1662                                               None
# 1663                                               None
# 1664                                               None
# 1665                                               None
# 1666                                               None
# 1667                                               None
# 1668                                               None
# 1669                                               None
# 1670                                               None
# 1671                                               None
# 1672                                               None
# 1673                                               None
# 1674                                               None
# 1675                                               None
# 1676                                               None
# 1677                                               None
# 1678  https://qualaroo.com/beginners-guide-to-cro/?i...
# 1679  http://danmaz74.me/2012/10/10/abalytics-js-cli...
#
#                                                    text      parent deleted  \
# 0                                  &quot;Adapter&quot;?   8124494.0    None
# 1     For the Romans, an often cited reason for the ...   9868765.0    None
# 2                              And that's all I need ;)   4030140.0    None
# 3     With a couple of books I reference often, I&#x...   8913265.0    None
# 4     On the other hand, 99.7% of my readers didn't ...   4757225.0    None
# 5     I&#x27;m not against nuclear, but also conside...   9765836.0    None
# 6     &gt; Companies are for making money<p>That&#x2...   6564375.0    None
# 7     Italy is pretty "private" about this. I person...   4767420.0    None
# 8     &quot;someone who turned because of what he sa...   5939415.0    None
# 9     You're welcome!<p>I didn't think about the cod...   4635880.0    None
# 10    You shouldn't need a marketing guru to know ab...   3608585.0    None
# 11    Yes, I still haven't published the pro website...   3146016.0    None
# 12    Beautiful - but I&#x27;d like to also see all ...   6306469.0    None
# 13    &quot;but not in the sense that most people th...   5996148.0    None
# 14                                 You&#x27;re welcome!   9969067.0    None
# 15    What&#x27;s the point of watching 4K video on ...   9329530.0    None
# 16    "essentially, all models are wrong, but some a...   3159594.0    None
# 17    My experience here in Italy is limited to few ...   8086158.0    None
# 18    Where did you get your data about incorporatin...   3407735.0    None
# 19    I remember from reading a biography that he go...   8189046.0    None
# 20    &quot;30% of the planet&#x27;s GDP&quot; more ...   7510790.0    None
# 21    Possible, yes. Very likely... from your handle...   6413742.0    None
# 22    See my edit to the previous comment - now I ac...   7880109.0    None
# 23    Regarding efficiency, you should simply add th...   9645021.0    None
# 24    Except we Europeans would pay for your kids ed...   9662342.0    None
# 25    From Italy, I always looked at the Netherland&...   6596794.0    None
# 26    In Italy we had a pretty big scandal because p...   3131112.0    None
# 27    I&#x27;ve never been a google+ basher, but I r...   7927423.0    None
# 28    <i>Obamacare &quot;is designed to be a fiscal ...   5968691.0    None
# 29    This is similar enough to experiences I had in...   6309422.0    None
# ...                                                 ...         ...     ...
# 1650  Ok, leave alone the "apps" - let's talk about ...   5696124.0    None
# 1651    Cool - so for FF there is already a solution :)   4030324.0    None
# 1652  Using solar especially for desalination will o...   9738683.0    None
# 1653  Then you should contact the antitrust authorit...   3030665.0    None
# 1654  I can&#x27;t volunteer at the moment, but it w...   7169888.0    None
# 1655  Why silly? Pride is a very strong motivation. ...   5880216.0    None
# 1656  Out of curiosity, why didn&#x27;t you use Immu...  10205716.0    None
# 1657  Shouldn&#x27;t an article about graphical prog...   6551931.0    None
# 1658  Hetzner. You should really add it to the options.   6555505.0    None
# 1659  Are there really quarterbacks who reason in eu...   6558715.0    None
# 1660  A new Cold War is unthinkable, but much colder...   7366005.0    None
# 1661  Pretty clever PR move by Elon Musk. Now, if Bo...   5080605.0    None
# 1662  Just sent it - let me know if you get it (you ...   8814025.0    None
# 1663  The tech is nice, but adding hashtags like thi...   6411922.0    None
# 1664  I really like mural.ly. It&#x27;s a very good ...   7882338.0    None
# 1665  To maintain the psychological impact it could ...   2941091.0    None
# 1666  Unless there are very very big deposits in you...   5459728.0    None
# 1667  &quot;Essentially, all models are wrong, but s...   6071684.0    None
# 1668  Looks like a fair solution, but the problem re...   6584433.0    None
# 1669  I would never have guessed. I wonder why this ...  10128829.0    None
# 1670  I didn&#x27;t think about this effect and prob...   9665886.0    None
# 1671  You just gave me a great idea for a future pos...   4659182.0    None
# 1672  That&#x27;s interesting, I&#x27;ll look into i...   6310269.0    None
# 1673  From what I understood, the biggest problem is...   9834296.0    None
# 1674       I&#x27;m curious now, what kind of guy am I?   8712526.0    None
# 1675  Not behind paywalls, I agree. Free of advertis...   8556331.0    None
# 1676  If 5% of cars really caused 90% of the polluti...   9506218.0    None
# 1677  I&#x27;m not an expert about AngularJS and we&...   9967453.0    None
# 1678                                                            NaN    None
# 1679                                                            NaN    None
#
#       dead  descendants        id ranking
# 0     None          NaN   8124572    None
# 1     None          NaN   9869850    None
# 2     None          NaN   4030164    None
# 3     None          NaN   8913948    None
# 4     None          NaN   4757283    None
# 5     None          NaN   9766956    None
# 6     None          NaN   6564467    None
# 7     None          NaN   4767492    None
# 8     None          NaN   5939584    None
# 9     None          NaN   4635893    None
# 10    None          NaN   3608849    None
# 11    None          NaN   3146139    None
# 12    None          NaN   6306654    None
# 13    None          NaN   5996262    None
# 14    None          NaN   9969154    None
# 15    None          NaN   9329620    None
# 16    None          NaN   3159680    None
# 17    None          NaN   8089150    None
# 18    None          NaN   3407852    None
# 19    None          NaN   8189161    None
# 20    None          NaN   7512372    None
# 21    None          NaN   6413945    None
# 22    None          NaN   7880150    None
# 23    None          NaN   9645185    None
# 24    None          NaN   9664236    None
# 25    None          NaN   6597602    None
# 26    None          NaN   3131335    None
# 27    None          NaN   7927605    None
# 28    None          NaN   5968997    None
# 29    None          NaN   6309598    None
# ...    ...          ...       ...     ...
# 1650  None          NaN   5697954    None
# 1651  None          NaN   4030348    None
# 1652  None          NaN   9738927    None
# 1653  None          NaN   3033100    None
# 1654  None          NaN   7170039    None
# 1655  None          NaN   5880252    None
# 1656  None          NaN  10206599    None
# 1657  None          NaN   6552426    None
# 1658  None          NaN   6556642    None
# 1659  None          NaN   6558858    None
# 1660  None          NaN   7366276    None
# 1661  None          NaN   5080860    None
# 1662  None          NaN   8814157    None
# 1663  None          NaN   6412944    None
# 1664  None          NaN   7882588    None
# 1665  None          NaN   2945058    None
# 1666  None          NaN   5459805    None
# 1667  None          NaN   6072147    None
# 1668  None          NaN   6584480    None
# 1669  None          NaN  10128856    None
# 1670  None          NaN   9666084    None
# 1671  None          NaN   4659195    None
# 1672  None          NaN   6310396    None
# 1673  None          NaN   9835475    None
# 1674  None          NaN   8712583    None
# 1675  None          NaN   8556461    None
# 1676  None          NaN   9506382    None
# 1677  None          NaN   9967518    None
# 1678  None          0.0   6385275    None
# 1679  None         20.0   4635778    None
#
# [1680 rows x 13 columns]
