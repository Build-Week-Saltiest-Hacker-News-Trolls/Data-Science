# %%
# set env variable to json credential file of google cloud

import os
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'my_key_file.json'

# %%
from google.cloud import bigquery
import time
import pandas as pd
import numpy as np

# %%
# setup client
bq_client = bigquery.Client()

# %%
# GETS SQL QUERY FOR 100 USERS (14,000-14,000) FROM SORTED TABLE OF MOST COMMENTS
# WHERE TOTAL COMMENTS IS SLIGHTLY ABOVE 100

QUERY = '''
        SELECT E.*, C.comments_count
        FROM `bigquery-public-data.hacker_news.full_201510` as E
        JOIN(
            SELECT *
            FROM(
                SELECT *
                FROM(
                    SELECT  `bigquery-public-data.hacker_news.full_201510`.by, COUNT(*) as comments_count
                    FROM `bigquery-public-data.hacker_news.full_201510`
                    GROUP BY `bigquery-public-data.hacker_news.full_201510`.by
                )  
                ORDER BY comments_count DESC
                LIMIT 9500
            )
            ORDER BY comments_count 
            LIMIT 100            
        ) C 
        ON E.by = C.by
        
        '''

# %%
import time
start = time.time()
df = bq_client.query(QUERY).to_dataframe()
end = time.time()
print(end - start)
# Out:
# 13.626693964004517

# %%
df.shape
# Out:
# (20089, 14)

# %%
users = df['by'].unique()
len(users)
# Out:
# 100

# %%
df.head()
# Out:
#            by  score        time title     type   url  \
# 0      dimino    NaN  1438628769  None  comment  None
# 1    jmngomes    NaN  1390823014  None  comment  None
# 2      cedsav    NaN  1194217292  None  comment  None
# 3  archivator    NaN  1398022736  None  comment  None
# 4    jherdman    NaN  1258725132  None  comment  None
#
#                                                 text     parent deleted  dead  \
# 0  I was going to write a little client library f...  9998227.0    None  None
# 1  Agreed, and I think it&#x27;s mainly because i...  7128883.0    None  None
# 2  I think you might be a bit too ambitious. <p>1...    76111.0    None  None
# 3  It&#x27;s either that or Twitter will be compl...  7618050.0    None  None
# 4  It seems to me that the goal of the App Store ...   952349.0    None  None
#
#    descendants       id ranking  comments_count
# 0          NaN  9998949    None             202
# 1          NaN  7129850    None             202
# 2          NaN    76129    None             200
# 3          NaN  7618200    None             201
# 4          NaN   952386    None             200

# %%
# DATA WRANGLING

# Drop unecessary columns
df_drop = df.drop(columns= ['score','title','url','deleted','dead','descendants','ranking'])

# Keep only comments in the dataframe
df_drop = df_drop[df_drop['type']=='comment']

#drop empty comments 
df_drop = df_drop[(df_drop['text'] != '')&(df_drop['text'] != np.nan)]

# Fix weird text encodings
import html
df_drop['text']=df_drop['text'].apply(str)
df_drop['text'] = df_drop['text'].apply(lambda x: html.unescape(x))

# Remove html tags from string
import re
def remove_html_tags(text):
   clean = re.compile('<.*?>')
   return re.sub(clean, '', text)
df_drop['text'] = df_drop['text'].apply(lambda x: remove_html_tags(x))

# Convert unix time to datetime object with date
from datetime import datetime
df_drop['time']=pd.to_datetime(df_drop['time'],unit='s') # for accuracy secs
#df_drop['time']=pd.to_datetime(df_drop['time']).dt.date # for just date

# %%
# Check only analyzing comments
df_drop['type'].value_counts()
# Out:
# comment    16300
# Name: type, dtype: int64

# %%
users = df_drop['by'].unique()
print(len(users))
# Out:
# 98

# %%
df_drop.head()
# Out:
#            by                time     type  \
# 0      dimino 2015-08-03 19:06:09  comment
# 1    jmngomes 2014-01-27 11:43:34  comment
# 2      cedsav 2007-11-04 23:01:32  comment
# 3  archivator 2014-04-20 19:38:56  comment
# 4    jherdman 2009-11-20 13:52:12  comment
#
#                                                 text     parent       id  \
# 0  I was going to write a little client library f...  9998227.0  9998949
# 1  Agreed, and I think it's mainly because it get...  7128883.0  7129850
# 2  I think you might be a bit too ambitious. 1. Y...    76111.0    76129
# 3  It's either that or Twitter will be completely...  7618050.0  7618200
# 4  It seems to me that the goal of the App Store ...   952349.0   952386
#
#    comments_count
# 0             202
# 1             202
# 2             200
# 3             201
# 4             200

# %%
# Populate sentiment analysis columns in dataframe
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

# %%
df_drop['neg']=np.zeros(df_drop.shape[0])
df_drop['pos']=np.zeros(df_drop.shape[0])
df_drop['neu']=np.zeros(df_drop.shape[0])

# %%
# OLD METHOD

# Adding sentiments to dataframe is computationally intensive
# On Martin's local computer 12,811 comments took ~24 min 

#import time
#start = time.time()

# populate vader sentiments in additional cols
#for idx,x in df_drop['text'].iteritems():
#    #print (idx,x)
    
#    df_drop['neg'][idx] = sia.polarity_scores(x)['neg']
#    df_drop['pos'][idx] = sia.polarity_scores(x)['pos']
#    df_drop['neu'][idx] = sia.polarity_scores(x)['neu']    
#end = time.time()
#print(end - start)

# %%
# NEW METHOD

# Using apply function (which uses compiled code) took 12,811 comments done in ~30s!

now=time.time()
df_drop['neg'] = df_drop['text'].apply(lambda x: sia.polarity_scores(x)['neg'])
df_drop['pos'] = df_drop['text'].apply(lambda x: sia.polarity_scores(x)['pos'])
df_drop['neu'] = df_drop['text'].apply(lambda x: sia.polarity_scores(x)['neu'])
print('sentiment cal took:',round(time.time()-now,2),'s')
# Out:
# sentiment cal took: 36.72 s

# %%
df_drop.head()
# Out:
#            by                time     type  \
# 0      dimino 2015-08-03 19:06:09  comment
# 1    jmngomes 2014-01-27 11:43:34  comment
# 2      cedsav 2007-11-04 23:01:32  comment
# 3  archivator 2014-04-20 19:38:56  comment
# 4    jherdman 2009-11-20 13:52:12  comment
#
#                                                 text     parent       id  \
# 0  I was going to write a little client library f...  9998227.0  9998949
# 1  Agreed, and I think it's mainly because it get...  7128883.0  7129850
# 2  I think you might be a bit too ambitious. 1. Y...    76111.0    76129
# 3  It's either that or Twitter will be completely...  7618050.0  7618200
# 4  It seems to me that the goal of the App Store ...   952349.0   952386
#
#    comments_count    neg    pos    neu
# 0             202  0.069  0.038  0.892
# 1             202  0.017  0.063  0.920
# 2             200  0.079  0.146  0.775
# 3             201  0.058  0.089  0.852
# 4             200  0.000  0.175  0.825

# %%
# Shrink the dataframe to 100 comments per user, where comment is not a pure neg or pos so that
# comment displayed is somewhat interesting and not just one word.

# %%
df_final = pd.DataFrame(data=None, columns=df_drop.columns)
df_user_most_pos = pd.DataFrame(data=None, columns=df_drop.columns)
df_user_most_neg = pd.DataFrame(data=None, columns=df_drop.columns)

for user in users:
    # Create a dataframe of only one user
    df_user = df_drop[df_drop['by'] == user]
    
    # Remove pure sentiments (removes pure one-word comments)
    df_user_unpure = df_user[(df_user['neg'] !=1) & (df_user['pos'] !=1)]
    
    # Submit first 100 comments of the unpure sentiments to final dataframe
    df_final = df_final.append(df_user_unpure[:100])
    
    # Submit max unpure neg/pos comment per user into dataframe
    df_temp = df_final[df_final['by'] == user]
    ix_neg = df_temp['neg'].idxmax(axis=0)
    df_user_most_neg = df_user_most_neg.append(df_temp.loc[ix_neg])
    ix_pos = df_temp['pos'].idxmax(axis=0)
    df_user_most_pos = df_user_most_pos.append(df_temp.loc[ix_pos])
    
df_final.shape
# Out:
# (9133, 10)

# %%
users = df_drop['by'].unique()
len(users)
# Out:
# 98

# %%
df_final.head(10)
# Out:
#          by                time     type  \
# 0    dimino 2015-08-03 19:06:09  comment
# 28   dimino 2015-05-15 22:10:46  comment
# 233  dimino 2015-07-29 15:42:01  comment
# 289  dimino 2015-06-15 18:08:22  comment
# 307  dimino 2015-07-11 19:07:04  comment
# 390  dimino 2015-06-26 17:05:05  comment
# 413  dimino 2015-06-02 23:18:16  comment
# 667  dimino 2015-07-10 21:57:28  comment
# 745  dimino 2015-05-28 20:45:24  comment
# 746  dimino 2015-05-29 02:06:40  comment
#
#                                                   text     parent       id  \
# 0    I was going to write a little client library f...  9998227.0  9998949
# 28   I would have sworn up and down, and bet all my...  9552927.0  9553993
# 233        Yeah, also the trauma and panic it incites.  9965941.0  9969346
# 289  I agree with everything you've written!  All I...  9720916.0  9720959
# 307  There are reasons other than "I disagree with ...  9867780.0  9871127
# 390  You say that like it'd take a weekend and a bu...  9786075.0  9786115
# 413  > Users can still have other perfectly reasona...  9649348.0  9649643
# 667  I came this close to not even knowing about th...  9866900.0  9867059
# 745  Price is a huge inhibitor for a mid-range Cano...  9621004.0  9621062
# 746  Oh certainly, I just wanted to make the point ...  9621930.0  9622329
#
#     comments_count    neg    pos    neu
# 0              202  0.069  0.038  0.892
# 28             202  0.088  0.069  0.844
# 233            202  0.459  0.165  0.376
# 289            202  0.096  0.149  0.756
# 307            202  0.224  0.000  0.776
# 390            202  0.000  0.152  0.848
# 413            202  0.063  0.175  0.762
# 667            202  0.000  0.057  0.943
# 745            202  0.123  0.217  0.660
# 746            202  0.000  0.130  0.870

# %%
# Random comments from the 100 users
df_random100 = df_final.sample(100)
df_random100.head(10)
# Out:
#                by                time     type  \
# 3389   ASneakyFox 2014-07-01 07:40:41  comment
# 3148        evanb 2014-08-20 14:49:35  comment
# 618       jkurnia 2014-04-22 17:23:32  comment
# 20     shadytrees 2009-08-30 00:38:03  comment
# 294       maneesh 2012-10-31 17:05:37  comment
# 9415   alexkearns 2010-08-23 19:40:17  comment
# 12445      acron0 2014-08-03 15:33:44  comment
# 4455      cmsmith 2015-06-05 18:10:02  comment
# 2928    droidist2 2013-06-01 16:07:33  comment
# 3440     twerquie 2014-10-23 15:22:54  comment
#
#                                                     text     parent       id  \
# 3389   The whole thing sounds like an episode of some...  7969301.0  7969558
# 3148   I think you mean unjustified.  Unjust usually ...  8202413.0  8202485
# 618    I would agree with these statements: Zidisha i...  7628325.0  7628991
# 20     > [Writers] ... are busily grafting the sophis...   793052.0   793874
# 294    Maybe the most powerful post I've ever read on...  4723342.0  4723878
# 9415                       Are you always this annoying?  1624561.0  1627769
# 12445  Any article or discussion that involves C/C++ ...  8127499.0  8128179
# 4455   And what happens to the local farmers and roof...  9666406.0  9667003
# 2928   Of course I wasn't saying that applies in ever...  5804497.0  5804528
# 3440   I really enjoy that trend. Tech is a dry topic...  8498502.0  8498601
#
#       comments_count    neg    pos    neu
# 3389             201  0.000  0.160  0.840
# 3148             201  0.163  0.292  0.545
# 618              202  0.041  0.211  0.748
# 20               200  0.112  0.095  0.793
# 294              201  0.000  0.205  0.795
# 9415             201  0.439  0.000  0.561
# 12445            200  0.000  0.000  1.000
# 4455             201  0.000  0.050  0.950
# 2928             200  0.000  0.133  0.867
# 3440             200  0.000  0.241  0.759

# %%
# Most negative comments
df_neg100 = df_final.sort_values(['neg'],ascending=False)[:100]
df_neg100.head(10)
# Out:
#                 by                time     type  \
# 7587    alexkearns 2011-04-24 07:44:02  comment
# 8827          kang 2012-05-28 15:24:19  comment
# 3249      twerquie 2014-06-23 18:48:58  comment
# 772     shadytrees 2014-08-31 19:38:17  comment
# 9831        j2labs 2013-06-15 03:18:41  comment
# 7563         yuchi 2012-06-26 17:46:15  comment
# 8300   kellysutton 2013-01-21 16:27:52  comment
# 15560      reddotX 2015-08-04 13:53:17  comment
# 6846         yuchi 2012-12-12 21:49:18  comment
# 8642       okasaki 2014-06-09 17:49:41  comment
#
#                                                     text      parent  \
# 7587   Stop spamming: http://news.ycombinator.com/sub...   2478465.0
# 8827                                        thats racist   4032524.0
# 3249                   You are fighting a losing battle.   7933460.0
# 772                                              My bad!   8245728.0
# 9831                                    painfully cheesy   5882834.0
# 7563                       Sorry, but this is a dupe! :\   4163034.0
# 8300                                          Rails. No.   5092095.0
# 15560                                what github fiasco?  10003348.0
# 6846              I hate the abuse of the word "meme"...   4912487.0
# 8642                                Discouraged by whom?   7869290.0
#
#              id comments_count    neg  pos    neu
# 7587    2478472            201  0.841  0.0  0.159
# 8827    4033741            201  0.800  0.0  0.200
# 3249    7933701            200  0.794  0.0  0.206
# 772     8250164            200  0.791  0.0  0.209
# 9831    5883794            201  0.773  0.0  0.227
# 7563    4163176            201  0.718  0.0  0.282
# 8300    5092132            200  0.688  0.0  0.312
# 15560  10003370            201  0.623  0.0  0.377
# 6846    4912662            201  0.612  0.0  0.388
# 8642    7869516            201  0.574  0.0  0.426

# %%
# Most positive comments
df_pos100 = df_final.sort_values(['pos'],ascending=False)[:100]
df_pos100.head(10)
# Out:
#                by                time     type  \
# 1129         domp 2007-04-03 02:28:35  comment
# 939     medianama 2010-03-07 19:15:11  comment
# 3890          dlf 2013-01-27 00:37:19  comment
# 10554         nav 2009-06-18 23:32:32  comment
# 11066     daviday 2012-06-02 17:36:34  comment
# 8808       jdunck 2013-01-10 21:56:25  comment
# 8975   arisAlexis 2015-07-21 08:54:08  comment
# 6600       mikeg8 2014-02-12 17:33:44  comment
# 4992       mikeg8 2012-03-24 22:05:40  comment
# 5887   shadytrees 2014-08-30 19:04:05  comment
#
#                                    text     parent       id comments_count  \
# 1129          Wow thats pretty amazing.     8396.0     8401            201
# 939                   Great. Thank You.  1173801.0  1173817            200
# 3890                     Happy to help.  5122079.0  5122473            202
# 10554                  Thanks. Was fun.   664341.0   664342            201
# 11066               Thanks for sharing!  4057945.0  4058591            202
# 8808                   Thanks, Matt. :)  5039861.0  5040042            201
# 8975               haha cool trolling!!  9921007.0  9921101            200
# 6600   Interesting perspective. Thanks.  7225297.0  7225758            200
# 4992         Interesting point. Thanks.  3750879.0  3750903            200
# 5887                   Please cheer up.  8246606.0  8247275            200
#
#        neg    pos    neu
# 1129   0.0  0.915  0.085
# 939    0.0  0.868  0.132
# 3890   0.0  0.865  0.135
# 10554  0.0  0.861  0.139
# 11066  0.0  0.857  0.143
# 8808   0.0  0.855  0.145
# 8975   0.0  0.855  0.145
# 6600   0.0  0.848  0.152
# 4992   0.0  0.848  0.152
# 5887   0.0  0.848  0.152

# %%
# Most single negative comment for each user
df_user_most_neg.head(10)
# Out:
#                 by                time     type  \
# 233         dimino 2015-07-29 15:42:01  comment
# 1462      jmngomes 2013-07-03 15:36:58  comment
# 8005        cedsav 2008-01-18 22:56:20  comment
# 8034    archivator 2013-04-19 07:09:10  comment
# 8969      jherdman 2012-08-03 17:23:59  comment
# 1384        sreque 2010-05-27 17:48:05  comment
# 3293     droidist2 2015-06-10 21:39:32  comment
# 3443  manaskarekar 2012-11-10 13:55:23  comment
# 8839           gdb 2014-12-24 18:32:15  comment
# 8300   kellysutton 2013-01-21 16:27:52  comment
#
#                                                    text     parent       id  \
# 233         Yeah, also the trauma and panic it incites.  9965941.0  9969346
# 1462  You just reminded me of the closing words of K...  5985041.0  5985229
# 8005                        ...says the developer snob.   100563.0   100571
# 8034  When fighting the institutions that write thes...  5575251.0  5575319
# 8969                         Yup! You're right. My bad.  4334441.0  4335028
# 1384  No one will argue with you that Perl isn't bet...  1384157.0  1384411
# 3293  And that insecurity manifests itself as a faca...  9695580.0  9695679
# 3443  This just sounds like desperate clawing of a d...  4766557.0  4766641
# 8839  The site should now be loading — sorry about t...  8793908.0  8793924
# 8300                                         Rails. No.  5092095.0  5092132
#
#      comments_count    neg    pos    neu
# 233             202  0.459  0.165  0.376
# 1462            202  0.268  0.000  0.732
# 8005            200  0.500  0.000  0.500
# 8034            201  0.382  0.000  0.618
# 8969            200  0.487  0.000  0.513
# 1384            202  0.233  0.000  0.767
# 3293            200  0.408  0.000  0.592
# 3443            201  0.361  0.139  0.500
# 8839            201  0.349  0.000  0.651
# 8300            200  0.688  0.000  0.312

# %%
# Most single positive comment for each user
df_user_most_pos.head(10)
# Out:
#                 by                time     type  \
# 3916        dimino 2015-07-28 17:55:30  comment
# 5075      jmngomes 2014-10-28 10:54:54  comment
# 6912        cedsav 2009-11-02 19:32:22  comment
# 4503    archivator 2012-05-14 21:31:49  comment
# 4140      jherdman 2010-06-12 14:21:23  comment
# 3283        sreque 2013-01-04 16:31:50  comment
# 4617     droidist2 2015-02-28 10:34:46  comment
# 7499  manaskarekar 2012-08-28 12:39:11  comment
# 3356           gdb 2012-05-29 20:25:35  comment
# 5779   kellysutton 2012-09-13 20:07:26  comment
#
#                                                    text     parent       id  \
# 3916                      To the law?  Yes, a huge one.  9962518.0  9963313
# 5075  Glad they now have a faster way to make inaccu...  8519820.0  8520320
# 6912  FWIW, I like the bookshelf metaphor, more huma...   917642.0   917665
# 4503  Definitely true on Linux with bash - .* will e...  3973375.0  3973430
# 4140  Zed loves Fossil SCM: http://www.fossil-scm.or...  1426016.0  1426031
# 3283  That is certainly false hyperbole. There a lot...  5008266.0  5008318
# 4617                                  LOL, brogrammers?  9122631.0  9123354
# 7499                      Thanks, I'll try that out. :)  4442634.0  4443339
# 3356         Ah, interesting. Yeah, would love a patch!  4039492.0  4039622
# 5779  Yes. https://github.com/lyondhill/socket.io-ru...  4518154.0  4518286
#
#      comments_count    neg    pos    neu
# 3916            202  0.000  0.556  0.444
# 5075            202  0.000  0.400  0.600
# 6912            200  0.000  0.416  0.584
# 4503            201  0.000  0.432  0.568
# 4140            200  0.000  0.481  0.519
# 3283            202  0.019  0.231  0.750
# 4617            200  0.000  0.779  0.221
# 7499            201  0.000  0.596  0.404
# 3356            201  0.000  0.758  0.242
# 5779            200  0.000  0.730  0.270

# %%
# Clean up columns and columns order to match desired PostgreSQL output

# %%
cols = df_final.columns.tolist()
cols
# Out:
# ['by',
#  'time',
#  'type',
#  'text',
#  'parent',
#  'id',
#  'comments_count',
#  'neg',
#  'pos',
#  'neu']

# %%
cols_final = cols[5:6] + cols[0:1] + cols[3:4] + cols[1:2] + cols[-3:]
cols_final
# Out:
# ['id', 'by', 'text', 'time', 'neg', 'pos', 'neu']

# %%
df_final_form = df_final[cols_final]
df_random100_form = df_random100[cols_final]
df_neg100_form = df_neg100[cols_final]
df_pos100_form = df_pos100[cols_final]
df_user_most_neg_form = df_user_most_neg[cols_final]
df_user_most_pos_form = df_user_most_pos[cols_final]

# %%
df_final_form.head(10)
# Out:
#           id      by                                               text  \
# 0    9998949  dimino  I was going to write a little client library f...
# 28   9553993  dimino  I would have sworn up and down, and bet all my...
# 233  9969346  dimino        Yeah, also the trauma and panic it incites.
# 289  9720959  dimino  I agree with everything you've written!  All I...
# 307  9871127  dimino  There are reasons other than "I disagree with ...
# 390  9786115  dimino  You say that like it'd take a weekend and a bu...
# 413  9649643  dimino  > Users can still have other perfectly reasona...
# 667  9867059  dimino  I came this close to not even knowing about th...
# 745  9621062  dimino  Price is a huge inhibitor for a mid-range Cano...
# 746  9622329  dimino  Oh certainly, I just wanted to make the point ...
#
#                    time    neg    pos    neu
# 0   2015-08-03 19:06:09  0.069  0.038  0.892
# 28  2015-05-15 22:10:46  0.088  0.069  0.844
# 233 2015-07-29 15:42:01  0.459  0.165  0.376
# 289 2015-06-15 18:08:22  0.096  0.149  0.756
# 307 2015-07-11 19:07:04  0.224  0.000  0.776
# 390 2015-06-26 17:05:05  0.000  0.152  0.848
# 413 2015-06-02 23:18:16  0.063  0.175  0.762
# 667 2015-07-10 21:57:28  0.000  0.057  0.943
# 745 2015-05-28 20:45:24  0.123  0.217  0.660
# 746 2015-05-29 02:06:40  0.000  0.130  0.870

# %%
df_random100_form.head(10)
# Out:
#             id          by                                               text  \
# 3389   7969558  ASneakyFox  The whole thing sounds like an episode of some...
# 3148   8202485       evanb  I think you mean unjustified.  Unjust usually ...
# 618    7628991     jkurnia  I would agree with these statements: Zidisha i...
# 20      793874  shadytrees  > [Writers] ... are busily grafting the sophis...
# 294    4723878     maneesh  Maybe the most powerful post I've ever read on...
# 9415   1627769  alexkearns                      Are you always this annoying?
# 12445  8128179      acron0  Any article or discussion that involves C/C++ ...
# 4455   9667003     cmsmith  And what happens to the local farmers and roof...
# 2928   5804528   droidist2  Of course I wasn't saying that applies in ever...
# 3440   8498601    twerquie  I really enjoy that trend. Tech is a dry topic...
#
#                      time    neg    pos    neu
# 3389  2014-07-01 07:40:41  0.000  0.160  0.840
# 3148  2014-08-20 14:49:35  0.163  0.292  0.545
# 618   2014-04-22 17:23:32  0.041  0.211  0.748
# 20    2009-08-30 00:38:03  0.112  0.095  0.793
# 294   2012-10-31 17:05:37  0.000  0.205  0.795
# 9415  2010-08-23 19:40:17  0.439  0.000  0.561
# 12445 2014-08-03 15:33:44  0.000  0.000  1.000
# 4455  2015-06-05 18:10:02  0.000  0.050  0.950
# 2928  2013-06-01 16:07:33  0.000  0.133  0.867
# 3440  2014-10-23 15:22:54  0.000  0.241  0.759

# %%
df_neg100_form.head(10)
# Out:
#              id           by  \
# 7587    2478472   alexkearns
# 8827    4033741         kang
# 3249    7933701     twerquie
# 772     8250164   shadytrees
# 9831    5883794       j2labs
# 7563    4163176        yuchi
# 8300    5092132  kellysutton
# 15560  10003370      reddotX
# 6846    4912662        yuchi
# 8642    7869516      okasaki
#
#                                                     text                time  \
# 7587   Stop spamming: http://news.ycombinator.com/sub... 2011-04-24 07:44:02
# 8827                                        thats racist 2012-05-28 15:24:19
# 3249                   You are fighting a losing battle. 2014-06-23 18:48:58
# 772                                              My bad! 2014-08-31 19:38:17
# 9831                                    painfully cheesy 2013-06-15 03:18:41
# 7563                       Sorry, but this is a dupe! :\ 2012-06-26 17:46:15
# 8300                                          Rails. No. 2013-01-21 16:27:52
# 15560                                what github fiasco? 2015-08-04 13:53:17
# 6846              I hate the abuse of the word "meme"... 2012-12-12 21:49:18
# 8642                                Discouraged by whom? 2014-06-09 17:49:41
#
#          neg  pos    neu
# 7587   0.841  0.0  0.159
# 8827   0.800  0.0  0.200
# 3249   0.794  0.0  0.206
# 772    0.791  0.0  0.209
# 9831   0.773  0.0  0.227
# 7563   0.718  0.0  0.282
# 8300   0.688  0.0  0.312
# 15560  0.623  0.0  0.377
# 6846   0.612  0.0  0.388
# 8642   0.574  0.0  0.426

# %%
df_pos100_form.head(10)
# Out:
#             id          by                              text  \
# 1129      8401        domp         Wow thats pretty amazing.
# 939    1173817   medianama                 Great. Thank You.
# 3890   5122473         dlf                    Happy to help.
# 10554   664342         nav                  Thanks. Was fun.
# 11066  4058591     daviday               Thanks for sharing!
# 8808   5040042      jdunck                  Thanks, Matt. :)
# 8975   9921101  arisAlexis              haha cool trolling!!
# 6600   7225758      mikeg8  Interesting perspective. Thanks.
# 4992   3750903      mikeg8        Interesting point. Thanks.
# 5887   8247275  shadytrees                  Please cheer up.
#
#                      time  neg    pos    neu
# 1129  2007-04-03 02:28:35  0.0  0.915  0.085
# 939   2010-03-07 19:15:11  0.0  0.868  0.132
# 3890  2013-01-27 00:37:19  0.0  0.865  0.135
# 10554 2009-06-18 23:32:32  0.0  0.861  0.139
# 11066 2012-06-02 17:36:34  0.0  0.857  0.143
# 8808  2013-01-10 21:56:25  0.0  0.855  0.145
# 8975  2015-07-21 08:54:08  0.0  0.855  0.145
# 6600  2014-02-12 17:33:44  0.0  0.848  0.152
# 4992  2012-03-24 22:05:40  0.0  0.848  0.152
# 5887  2014-08-30 19:04:05  0.0  0.848  0.152

# %%
df_user_most_neg_form.head(10)
# Out:
#            id            by  \
# 233   9969346        dimino
# 1462  5985229      jmngomes
# 8005   100571        cedsav
# 8034  5575319    archivator
# 8969  4335028      jherdman
# 1384  1384411        sreque
# 3293  9695679     droidist2
# 3443  4766641  manaskarekar
# 8839  8793924           gdb
# 8300  5092132   kellysutton
#
#                                                    text                time  \
# 233         Yeah, also the trauma and panic it incites. 2015-07-29 15:42:01
# 1462  You just reminded me of the closing words of K... 2013-07-03 15:36:58
# 8005                        ...says the developer snob. 2008-01-18 22:56:20
# 8034  When fighting the institutions that write thes... 2013-04-19 07:09:10
# 8969                         Yup! You're right. My bad. 2012-08-03 17:23:59
# 1384  No one will argue with you that Perl isn't bet... 2010-05-27 17:48:05
# 3293  And that insecurity manifests itself as a faca... 2015-06-10 21:39:32
# 3443  This just sounds like desperate clawing of a d... 2012-11-10 13:55:23
# 8839  The site should now be loading — sorry about t... 2014-12-24 18:32:15
# 8300                                         Rails. No. 2013-01-21 16:27:52
#
#         neg    pos    neu
# 233   0.459  0.165  0.376
# 1462  0.268  0.000  0.732
# 8005  0.500  0.000  0.500
# 8034  0.382  0.000  0.618
# 8969  0.487  0.000  0.513
# 1384  0.233  0.000  0.767
# 3293  0.408  0.000  0.592
# 3443  0.361  0.139  0.500
# 8839  0.349  0.000  0.651
# 8300  0.688  0.000  0.312

# %%
df_user_most_pos_form.head(10)
# Out:
#            id            by  \
# 3916  9963313        dimino
# 5075  8520320      jmngomes
# 6912   917665        cedsav
# 4503  3973430    archivator
# 4140  1426031      jherdman
# 3283  5008318        sreque
# 4617  9123354     droidist2
# 7499  4443339  manaskarekar
# 3356  4039622           gdb
# 5779  4518286   kellysutton
#
#                                                    text                time  \
# 3916                      To the law?  Yes, a huge one. 2015-07-28 17:55:30
# 5075  Glad they now have a faster way to make inaccu... 2014-10-28 10:54:54
# 6912  FWIW, I like the bookshelf metaphor, more huma... 2009-11-02 19:32:22
# 4503  Definitely true on Linux with bash - .* will e... 2012-05-14 21:31:49
# 4140  Zed loves Fossil SCM: http://www.fossil-scm.or... 2010-06-12 14:21:23
# 3283  That is certainly false hyperbole. There a lot... 2013-01-04 16:31:50
# 4617                                  LOL, brogrammers? 2015-02-28 10:34:46
# 7499                      Thanks, I'll try that out. :) 2012-08-28 12:39:11
# 3356         Ah, interesting. Yeah, would love a patch! 2012-05-29 20:25:35
# 5779  Yes. https://github.com/lyondhill/socket.io-ru... 2012-09-13 20:07:26
#
#         neg    pos    neu
# 3916  0.000  0.556  0.444
# 5075  0.000  0.400  0.600
# 6912  0.000  0.416  0.584
# 4503  0.000  0.432  0.568
# 4140  0.000  0.481  0.519
# 3283  0.019  0.231  0.750
# 4617  0.000  0.779  0.221
# 7499  0.000  0.596  0.404
# 3356  0.000  0.758  0.242
# 5779  0.000  0.730  0.270

# %%
# Save to local json

df_final_form.to_json(r'output/tiny_data_100x100.json')
df_random100_form.to_json(r'output/tiny_random100.json')
df_neg100_form.to_json(r'output/tiny_neg100.json')
df_pos100_form.to_json(r'output/tiny_pos100.json') 
df_user_most_neg_form.to_json(r'output/tiny_neg100_per_user.json') 
df_user_most_pos_form.to_json(r'output/tiny_pos100_per_user.json')

# %%
# Save to local csv

df_final_form.to_csv('output/tiny_data_100x100.csv', index=False)
df_random100_form.to_csv('output/tiny_random100.csv', index=False)
df_neg100_form.to_csv('output/tiny_neg100.csv', index=False)
df_pos100_form.to_csv('output/tiny_pos100.csv', index=False)
df_user_most_neg_form.to_csv('output/tiny_neg100_per_user.csv', index=False)
df_user_most_pos_form.to_csv('output/tiny_pos100_per_user.csv', index=False)

# %%
# Load csv's to Postgresql

# %%
# CLEAN OUT TABLES (IF NEEDED)
#pg_curs.execute('DROP TABLE tiny_data_100x100')
#pg_curs.execute('DROP TABLE tiny_random100')
#pg_curs.execute('DROP TABLE tiny_neg100')
#pg_curs.execute('DROP TABLE tiny_pos100')
#pg_curs.execute('DROP TABLE tiny_neg100_per_user')
#pg_curs.execute('DROP TABLE tiny_pos100_per_user')
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# <ipython-input-60-1a7d55c4f3c2> in <module>
#       1 # CLEAN OUT TABLES (IF NEEDED)
# ----> 2 pg_curs.execute('DROP TABLE tiny_data')
#       3 #pg_curs.execute('DROP TABLE tiny_data_100x100')
#       4 #pg_curs.execute('DROP TABLE tiny_random100')
#       5 #pg_curs.execute('DROP TABLE tiny_neg100')
#
# UndefinedTable: table "tiny_data" does not exist

# %%
# ROLLBACK (IF NEEDED)
pg_curs.execute("ROLLBACK")

# %%
import sqlite3
import psycopg2

# %%
# CONFIGURE YOUR OWN USER AND PASSWORD

dbname = 'dfoaqcagkvg30j'
user = ''
password = ''
host = 'ec2-174-129-252-226.compute-1.amazonaws.com'

# %%
pg_conn = psycopg2.connect(dbname=dbname,user=user,password=password,host=host)

# %%
pg_curs = pg_conn.cursor()

# %%
create_tiny_data_100x100 = '''
CREATE TABLE tiny_data_100x100 (
    comment_ID SERIAL PRIMARY KEY,
    author VARCHAR(100),
    comment_Text VARCHAR(10000),
    time DATE,
    neg FLOAT,
    pos FLOAT,
    neu FLOAT
)
'''

pg_curs.execute(create_tiny_data_100x100)

# %%
import csv

# %%
# Insert tiny_data.csv line by line into table
start = time.time()

with open('output/tiny_data_100x100.csv', newline='') as csvfile:
    reader = csv.reader(csvfile)
    next(reader)  # Skip first row of column names
    for row in reader:
        pg_curs.execute('INSERT INTO tiny_data_100x100 VALUES \
                        (%s, %s, %s, %s, %s, %s, %s)', row)
        
end = time.time()
print(end - start)
# Out:
# 103.07400226593018

# %%
# NOW DO THE SAME FOR OTHER TABLES...

# THESE SHOULD BE DONW WITH A FUNCTION!!!!!

# %%
# Tiny_random100
create_tiny_random100 = '''
CREATE TABLE tiny_random100 (
    comment_ID SERIAL PRIMARY KEY,
    author VARCHAR(100),
    comment_Text VARCHAR(10000),
    time DATE,
    neg FLOAT,
    pos FLOAT,
    neu FLOAT
)
'''

pg_curs.execute(create_tiny_random100)

# %%
with open('output/tiny_random100.csv', newline='') as csvfile:
    reader = csv.reader(csvfile)
    next(reader)  # Skip first row of column names
    for row in reader:
        pg_curs.execute('INSERT INTO tiny_random100 VALUES \
                        (%s, %s, %s, %s, %s, %s, %s)', row)

# %%
# Tiny_neg100
create_tiny_neg100 = '''
CREATE TABLE tiny_neg100 (
    comment_ID SERIAL PRIMARY KEY,
    author VARCHAR(100),
    comment_Text VARCHAR(10000),
    time DATE,
    neg FLOAT,
    pos FLOAT,
    neu FLOAT
)
'''

pg_curs.execute(create_tiny_neg100)

# %%
with open('output/tiny_neg100.csv', newline='') as csvfile:
    reader = csv.reader(csvfile)
    next(reader)  # Skip first row of column names
    for row in reader:
        pg_curs.execute('INSERT INTO tiny_neg100 VALUES \
                        (%s, %s, %s, %s, %s, %s, %s)', row)

# %%
# Tiny_pos100
create_tiny_pos100 = '''
CREATE TABLE tiny_pos100 (
    comment_ID SERIAL PRIMARY KEY,
    author VARCHAR(100),
    comment_Text VARCHAR(10000),
    time DATE,
    neg FLOAT,
    pos FLOAT,
    neu FLOAT
)
'''

pg_curs.execute(create_tiny_pos100)

# %%
with open('output/tiny_pos100.csv', newline='') as csvfile:
    reader = csv.reader(csvfile)
    next(reader)  # Skip first row of column names
    for row in reader:
        pg_curs.execute('INSERT INTO tiny_pos100 VALUES \
                        (%s, %s, %s, %s, %s, %s, %s)', row)

# %%
# Tiny_neg100_per_user
create_tiny_neg100_per_user = '''
CREATE TABLE tiny_neg100_per_user (
    comment_ID SERIAL PRIMARY KEY,
    author VARCHAR(100),
    comment_Text VARCHAR(10000),
    time DATE,
    neg FLOAT,
    pos FLOAT,
    neu FLOAT
)
'''

pg_curs.execute(create_tiny_neg100_per_user)

# %%
with open('output/tiny_neg100_per_user.csv', newline='') as csvfile:
    reader = csv.reader(csvfile)
    next(reader)  # Skip first row of column names
    for row in reader:
        pg_curs.execute('INSERT INTO tiny_neg100_per_user VALUES \
                        (%s, %s, %s, %s, %s, %s, %s)', row)

# %%
# Tiny_pos100_per_user
create_tiny_pos100_per_user = '''
CREATE TABLE tiny_pos100_per_user (
    comment_ID SERIAL PRIMARY KEY,
    author VARCHAR(100),
    comment_Text VARCHAR(10000),
    time DATE,
    neg FLOAT,
    pos FLOAT,
    neu FLOAT
)
'''

pg_curs.execute(create_tiny_pos100_per_user)

# %%
with open('output/tiny_pos100_per_user.csv', newline='') as csvfile:
    reader = csv.reader(csvfile)
    next(reader)  # Skip first row of column names
    for row in reader:
        pg_curs.execute('INSERT INTO tiny_pos100_per_user VALUES \
                        (%s, %s, %s, %s, %s, %s, %s)', row)
